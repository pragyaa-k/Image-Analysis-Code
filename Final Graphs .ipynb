# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
results_EMM_live= r"/Users/Prags/Desktop/S. pombe image data/161024_AV1200_EMM_Live/Tif_Images/Results_Tables/EMM_Live_All.csv"
# results_EMM_fixed = r"/Users/Prags/Desktop/S. pombe image data/301024 AV1200 EMM Fixed/Tif_Images/Results_Tables/EMM_Fixed_all.csv"

df_EMM_live = pd.read_csv(results_EMM_live)
# df_EMM_fixed = pd.read_csv(results_EMM_fixed)

bin_width = 0.3  # Desired bin width
# Create bins with the specified width
EMM_live_bins = np.arange(min(df_EMM_live["Area"]), max(df_EMM_live["Area"]) + bin_width, bin_width)
#EMM_fixed_bins = np.arange(min(df_EMM_fixed["Area"]), max(df_EMM_fixed["Area"]) + bin_width, bin_width)


plt.hist(df_EMM_live["Area"], bins=EMM_live_bins, color='g', alpha=0.7, label = "EMM Live")
#plt.hist(df_EMM_fixed["Area"], bins=EMM_fixed_bins, color='b', alpha=0.5, label = "YES")

plt.xlabel('Area of Nucleus (microns$^2$)') 
plt.ylabel('Frequency')
plt.title('Area of Different Nuclei in EMM live ROIs') 
plt.legend(title="Colour Key")

plt.show()

# %%
#results_EMM_live= r"/Users/Prags/Desktop/S. pombe image data/161024_AV1200_EMM_Live/Tif_Images/Results_Tables/EMM_Live_All.csv"
results_EMM_fixed = r"/Users/Prags/Desktop/S. pombe image data/301024 AV1200 EMM Fixed/Tif_Images/Results_Tables/EMM_Fixed_all.csv"

#df_EMM_live = pd.read_csv(results_EMM_live)
df_EMM_fixed = pd.read_csv(results_EMM_fixed)

bin_width = 0.3  # Desired bin width
# Create bins with the specified width
#EMM_live_bins = np.arange(min(df_EMM_live["Area"]), max(df_EMM_live["Area"]) + bin_width, bin_width)
EMM_fixed_bins = np.arange(min(df_EMM_fixed["Area"]), max(df_EMM_fixed["Area"]) + bin_width, bin_width)


#plt.hist(df_EMM_live["Area"], bins=EMM_live_bins, color='g', alpha=0.7, label = "EMM")
plt.hist(df_EMM_fixed["Area"], bins=EMM_fixed_bins, color='r', alpha=0.5, label = "EMM Fixed")

plt.xlabel('Area of Nucleus (microns$^2$)') 
plt.ylabel('Frequency')
plt.title('Area of Different Nuclei in EMM Fixed ROIs') 
plt.legend(title="Colour Key")

plt.show()

# %%
results_EMM_live= r"/Users/Prags/Desktop/S. pombe image data/161024_AV1200_EMM_Live/Tif_Images/Results_Tables/EMM_Live_All.csv"
results_EMM_fixed = r"/Users/Prags/Desktop/S. pombe image data/301024 AV1200 EMM Fixed/Tif_Images/Results_Tables/EMM_Fixed_all.csv"

df_EMM_live = pd.read_csv(results_EMM_live)
df_EMM_fixed = pd.read_csv(results_EMM_fixed)

bin_width = 0.3  # Desired bin width
# Create bins with the specified width
EMM_live_bins = np.arange(min(df_EMM_live["Area"]), max(df_EMM_live["Area"]) + bin_width, bin_width)
EMM_fixed_bins = np.arange(min(df_EMM_fixed["Area"]), max(df_EMM_fixed["Area"]) + bin_width, bin_width)


plt.hist(df_EMM_live["Area"], bins=EMM_live_bins, color='g', alpha=0.7, label = "EMM Live")
plt.hist(df_EMM_fixed["Area"], bins=EMM_fixed_bins, color='r', alpha=0.5, label = "EMM Fixed")

plt.xlabel('Area of Nucleus (microns$^2$)') 
plt.ylabel('Frequency')
plt.title('Area of Different Nuclei in EMM Fixed ROIs vs EMM Live ROIS') 
plt.legend(title="Colour Key")


plt.show()

# %%
results_YES_fixed = r"/Users/Prags/Desktop/S. pombe image data/241009_AV1200_YES_Fixed/YES_Fixed_All.csv"


df_YES_fixed = pd.read_csv(results_EMM_fixed)

bin_width = 0.3  # Desired bin width
# Create bins with the specified width

YES_fixed_bins = np.arange(min(df_YES_fixed["Area"]), max(df_YES_fixed["Area"]) + bin_width, bin_width)



plt.hist(df_YES_fixed["Area"], bins=YES_fixed_bins, color='r', alpha=0.5, label = "YES Fixed")

plt.xlabel('Area of Nucleus (microns$^2$)') 
plt.ylabel('Frequency')
plt.title('Area of Different Nuclei in YES Fixed ROIs') 
plt.legend(title="Colour Key")

plt.show()

# %%
results_YES_live= r"/Users/Prags/Desktop/S. pombe image data/241009_AV1200_YES_Live/Tif_Images/Results_Tables/YES_Live_all.csv"
# results_EMM_fixed = r"/Users/Prags/Desktop/S. pombe image data/301024 AV1200 EMM Fixed/Tif_Images/Results_Tables/EMM_Fixed_all.csv"

df_YES_live = pd.read_csv(results_YES_live)
# df_EMM_fixed = pd.read_csv(results_EMM_fixed)

bin_width = 0.3  # Desired bin width
# Create bins with the specified width
YES_live_bins = np.arange(min(df_YES_live["Area"]), max(df_YES_live["Area"]) + bin_width, bin_width)
#EMM_fixed_bins = np.arange(min(df_EMM_fixed["Area"]), max(df_EMM_fixed["Area"]) + bin_width, bin_width)


plt.hist(df_YES_live["Area"], bins=YES_live_bins, color='g', alpha=0.7, label = "YES Live")
#plt.hist(df_EMM_fixed["Area"], bins=EMM_fixed_bins, color='b', alpha=0.5, label = "YES")

plt.xlabel('Area of Nucleus (microns$^2$)') 
plt.ylabel('Frequency')
plt.title('Area of Different Nuclei in YES live ROIs') 
plt.legend(title="Colour Key")

plt.show()

# %%
results_YES_live= r"/Users/Prags/Desktop/S. pombe image data/241009_AV1200_YES_Live/Tif_Images/Results_Tables/YES_Live_all.csv"
results_YES_fixed = r"/Users/Prags/Desktop/S. pombe image data/241009_AV1200_YES_Fixed/YES_Fixed_All.csv"
df_YES_live = pd.read_csv(results_YES_live)
df_YES_fixed = pd.read_csv(results_YES_fixed)

bin_width = 0.3  # Desired bin width
# Create bins with the specified width
YES_live_bins = np.arange(min(df_YES_live["Area"]), max(df_YES_live["Area"]) + bin_width, bin_width)
YES_fixed_bins = np.arange(min(df_YES_fixed["Area"]), max(df_YES_fixed["Area"]) + bin_width, bin_width)


plt.hist(df_YES_live["Area"], bins=YES_live_bins, color='g', alpha=0.7, label = "YES Live")
plt.hist(df_YES_fixed["Area"], bins=YES_fixed_bins, color='r', alpha=0.5, label = "YES Fixed")

plt.xlabel('Area of Nucleus (microns$^2$)') 
plt.ylabel('Frequency')
plt.title('Area of Different Nuclei in YES Fixed ROIs vs YES Live ROIS') 
plt.legend(title="Colour Key")


plt.show()

# %%
results_EMMN= r"/Users/Prags/Desktop/S. pombe image data/131124 AV1200 EMM-N Fixed/Tif_Images/Results_Tables/EMMN_Fixed_all.csv"
# results_EMM_fixed = r"/Users/Prags/Desktop/S. pombe image data/301024 AV1200 EMM Fixed/Tif_Images/Results_Tables/EMM_Fixed_all.csv"

df_EMMN = pd.read_csv(results_EMMN)
# df_EMM_fixed = pd.read_csv(results_EMM_fixed)

bin_width = 0.3  # Desired bin width
# Create bins with the specified width
EMMN_bins = np.arange(min(df_EMMN["Area"]), max(df_EMMN["Area"]) + bin_width, bin_width)
#EMM_fixed_bins = np.arange(min(df_EMM_fixed["Area"]), max(df_EMM_fixed["Area"]) + bin_width, bin_width)


plt.hist(df_EMMN["Area"], bins=EMMN_bins, color='g', alpha=0.7, label = "EMM-N Fixed")
#plt.hist(df_EMM_fixed["Area"], bins=EMM_fixed_bins, color='b', alpha=0.5, label = "YES")

plt.xlabel('Area of Nucleus (microns$^2$)') 
plt.ylabel('Frequency')
plt.title('Area of Different Nuclei in EMM-N Fixed ROIs') 
plt.legend(title="Colour Key")

plt.show()

# %%
results_both= r"/Users/Prags/Desktop/S. pombe image data/131124 AV1200 EMM and EMM-N Fixed/Tif_Images/Results_Tables/EMM_and_EMMN_Fixed_all.csv"
# results_EMM_fixed = r"/Users/Prags/Desktop/S. pombe image data/301024 AV1200 EMM Fixed/Tif_Images/Results_Tables/EMM_Fixed_all.csv"

df_both = pd.read_csv(results_both)
# df_EMM_fixed = pd.read_csv(results_EMM_fixed)

bin_width = 0.3  # Desired bin width
# Create bins with the specified width
both_bins = np.arange(min(df_both["Area"]), max(df_both["Area"]) + bin_width, bin_width)
#EMM_fixed_bins = np.arange(min(df_EMM_fixed["Area"]), max(df_EMM_fixed["Area"]) + bin_width, bin_width)


plt.hist(df_both["Area"], bins=both_bins, color='r', alpha=0.7)
#plt.hist(df_EMM_fixed["Area"], bins=EMM_fixed_bins, color='b', alpha=0.5, label = "YES")

plt.xlabel('Area of Nucleus (microns$^2$)') 
plt.ylabel('Frequency')
plt.title('Area of Different Nuclei of cells grown in EMM and EMM-N Fixed ROIs') 


plt.show()
