# %%
# import important libraries 
import os
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
dish_path_sc = os.path.join("/Users/Prags/Desktop/241009 AV1200 YES Sc Fixed/Tif_Images", "YES_Fixed_Sc_All.csv")
dish_path_pk = os.path.join("/Users/Prags/Desktop/241009 AV1200 YES Pk Fixed/Tif_Images", "YES_Fixed_PK_All.csv")

df_sc = pd.read_csv(dish_path_sc)
df_pk = pd.read_csv(dish_path_pk)

df_fixed_all_list = [df_sc,df_pk]
df_fixed_all = pd.concat(df_fixed_all_list)
df_fixed_all.to_csv(os.path.join("/Users/Prags/Desktop/241009 AV1200 YES Pk Fixed/Tif_Images", "Fixed_All.csv"))

# %%
plt.hist(df_sc["Area"], bins=30, color='g', alpha=0.7)
plt.hist(df_pk["Area"], bins=60, color='r', alpha=0.7)
plt.xlabel('Area of Nucleus microns$^2$') 
plt.ylabel('Frequency')  
plt.title('Area of different nuclei')
# Out:
# Text(0.5, 1.0, 'Area of different nuclei')

# %%
plt.hist(df_fixed_all["Area"], bins=30, color='g', alpha=0.7)
plt.xlabel('Area of Nucleus microns$^2$') 
plt.ylabel('Frequency')  
plt.title('Area of different nuclei')
# Out:
# Text(0.5, 1.0, 'Area of different nuclei')

# %%
df_fixed_all.describe()
# Out:
#         Unnamed: 0                      Area    Mean     Min     Max  \
# count  3843.000000  3843.000000  3843.000000  3843.0  3843.0  3843.0
# mean    102.872495   103.872495     4.782906   255.0   255.0   255.0
# std      66.627988    66.627988     1.247800     0.0     0.0     0.0
# min       0.000000     1.000000     0.141000   255.0   255.0   255.0
# 25%      48.000000    49.000000     4.202000   255.0   255.0   255.0
# 50%      96.000000    97.000000     4.835000   255.0   255.0   255.0
# 75%     150.000000   151.000000     5.539000   255.0   255.0   255.0
# max     270.000000   271.000000    19.142000   255.0   255.0   255.0
#
#              Circ.           AR        Round     Solidity
# count  3843.000000  3843.000000  3843.000000  3843.000000
# mean      0.915329     1.208118     0.861999     0.949165
# std       0.061338     0.391856     0.118953     0.014664
# min       0.346000     1.003000     0.164000     0.723000
# ...
